# %%
import tensorflow as tf
#from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD, Adam

# %%
#https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz从这个网址下载数据集

#导入数据
x_train = np.load('E:/network assessment/x_train.npy')
y_train = np.load('E:/network assessment/y_train.npy')
print(x_train.shape, y_train.shape)   # 输出训练集样本和标签的大小
# Out:
# (60000, 28, 28) (60000,)

# %%
# 设置图形布局
fig, axes = plt.subplots(1, 15, figsize=(15, 5))

# 可视化前 5 张图片，确认数据准确
for i in range(15):
    axes[i].imshow(x_train[i], cmap='gray')
    axes[i].set_title(f"Label: {y_train[i]}")
    axes[i].axis('off')  # 关闭坐标轴显示

plt.show()

# %%
# 筛选标签为 5 的样本
indices = np.where(y_train == 5)[0]  # 找到标签为 5 的索引
selected_images = x_train[indices[:10]]  # 获取前 10 张图片

# 设置图形布局
fig, axes = plt.subplots(1, 10, figsize=(15, 5))

# 可视化标签为 5 的前 10 张图片
for i, img in enumerate(selected_images):
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Label: 5")
    axes[i].axis('off')  # 关闭坐标轴显示

plt.show()

# %%
x_train = np.load('E:/network assessment/x_train.npy')
y_train = np.load('E:/network assessment/y_train.npy')
x_test = np.load('E:/network assessment/x_test.npy')
y_test = np.load('E:/network assessment/y_test.npy')

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# 加载并预处理 MNIST 数据集
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# 数据归一化到 [0, 1] 范围，并调整形状以适配 CNN 输入
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# 添加一个维度，将数据从 (28, 28) 转为 (28, 28, 1)，适配卷积层
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# 将标签转换为独热编码
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# 检查数据形状
print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")
# Out:
# x_train shape: (60000, 28, 28, 1), y_train shape: (60000, 10)
# x_test shape: (10000, 28, 28, 1), y_test shape: (10000, 10)

# %%
# 构建卷积神经网络
model = models.Sequential([
    # 第一层卷积层 + 最大池化层
    layers.Conv2D(filters=16, kernel_size=(2, 2), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D(pool_size=(2, 2)),

    # 第二层卷积层 + 最大池化层
    layers.Conv2D(filters=32, kernel_size=(2, 2), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),

    # 第三层卷积层
    layers.Conv2D(filters=64, kernel_size=(2, 2), activation='relu'),

    # Flatten 将多维特征展开为一维
    layers.Flatten(),

    layers.Dropout(0.5),

    # 全连接层
    layers.Dense(64, activation='relu'),

    # 输出层
    layers.Dense(10, activation='softmax')  # 输出概率分布，10 类
])

# 编译模型
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 打印模型结构
model.summary()

# 训练模型
history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=64, 
                    validation_split=0.2)

# 评估模型
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Accuracy: {test_accuracy:.4f}")

# 可视化训练过程
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 27, 27, 16)        80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 64)          8256
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                102464
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 113,530
# Trainable params: 113,530
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0
loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0368 - val_accuracy: 0.9910
# Epoch 22/200
# 48000/48000 [==============================] - 13s 280us/sample - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.0338 - val_accuracy: 0.9919
# Epoch 23/200
# 48000/48000 [==============================] - 14s 287us/sample - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0350 - val_accuracy: 0.9917
# Epoch 24/200
# 48000/48000 [==============================] - 14s 286us/sample - loss: 0.0139 - accuracy: 0.9952 - val_loss: 0.0316 - val_accuracy: 0.9922
# Epoch 25/200
# 48000/48000 [==============================] - 15s 303us/sample - loss: 0.0137 - accuracy: 0.9950 - val_loss: 0.0345 - val_accuracy: 0.9914
# Epoch 26/200
# 48000/48000 [==============================] - 14s 290us/sample - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0378 - val_accuracy: 0.9917
# Epoch 27/200
# 48000/48000 [==============================] - 13s 279us/sample - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0380 - val_accuracy: 0.9915
# Epoch 28/200
# 48000/48000 [==============================] - 14s 297us/sample - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0348 - val_accuracy: 0.9923
# Epoch 29/200
# 48000/48000 [==============================] - 10s 201us/sample - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.0365 - val_accuracy: 0.9926
# Epoch 30/200
# 48000/48000 [==============================] - 6s 128us/sample - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.0420 - val_accuracy: 0.9903
# Epoch 31/200
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0363 - val_accuracy: 0.9918
# Epoch 32/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0349 - val_accuracy: 0.9918
# Epoch 33/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0405 - val_accuracy: 0.9913
# Epoch 34/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0437 - val_accuracy: 0.9919
# Epoch 35/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0458 - val_accuracy: 0.9909
# Epoch 36/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.0386 - val_accuracy: 0.9918
# Epoch 37/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0422 - val_accuracy: 0.9919
# Epoch 38/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0362 - val_accuracy: 0.9924
# Epoch 39/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0411 - val_accuracy: 0.9923
# Epoch 40/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0338 - val_accuracy: 0.9917
# Epoch 41/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0393 - val_accuracy: 0.9922
# Epoch 42/200
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.0339 - val_accuracy: 0.9929
# Epoch 43/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0354 - val_accuracy: 0.9930
# Epoch 44/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0339 - val_accuracy: 0.9934
# Epoch 45/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.0374 - val_accuracy: 0.9922
# Epoch 46/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0379 - val_accuracy: 0.9927
# Epoch 47/200
# 48000/48000 [==============================] - 6s 129us/sample - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0397 - val_accuracy: 0.9926
# Epoch 48/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0331 - val_accuracy: 0.9927
# Epoch 49/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0423 - val_accuracy: 0.9915
# Epoch 50/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.0505 - val_accuracy: 0.9905
# Epoch 51/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0383 - val_accuracy: 0.9928
# Epoch 52/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.0407 - val_accuracy: 0.9915
# Epoch 53/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.0406 - val_accuracy: 0.9915
# Epoch 54/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0406 - val_accuracy: 0.9920
# Epoch 55/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0418 - val_accuracy: 0.9924
# Epoch 56/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0474 - val_accuracy: 0.9915
# Epoch 57/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0415 - val_accuracy: 0.9922
# Epoch 58/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0445 - val_accuracy: 0.9914
# Epoch 59/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0426 - val_accuracy: 0.9916
# Epoch 60/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0534 - val_accuracy: 0.9916
# Epoch 61/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0469 - val_accuracy: 0.9922
# Epoch 62/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0526 - val_accuracy: 0.9916
# Epoch 63/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0417 - val_accuracy: 0.9927
# Epoch 64/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0408 - val_accuracy: 0.9922
# Epoch 65/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0388 - val_accuracy: 0.9923
# Epoch 66/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0439 - val_accuracy: 0.9927
# Epoch 67/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0402 - val_accuracy: 0.9925
# Epoch 68/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0423 - val_accuracy: 0.9923
# Epoch 69/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.0443 - val_accuracy: 0.9920
# Epoch 70/200
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0417 - val_accuracy: 0.9930
# Epoch 71/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0411 - val_accuracy: 0.9925
# Epoch 72/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0485 - val_accuracy: 0.9926
# Epoch 73/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0409 - val_accuracy: 0.9929
# Epoch 74/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0421 - val_accuracy: 0.9923
# Epoch 75/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0466 - val_accuracy: 0.9924
# Epoch 76/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0467 - val_accuracy: 0.9927
# Epoch 77/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0477 - val_accuracy: 0.9927
# Epoch 78/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0541 - val_accuracy: 0.9917
# Epoch 79/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0506 - val_accuracy: 0.9925
# Epoch 80/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0452 - val_accuracy: 0.9925
# Epoch 81/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0524 - val_accuracy: 0.9923
# Epoch 82/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0481 - val_accuracy: 0.9927
# Epoch 83/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0497 - val_accuracy: 0.9928
# Epoch 84/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0530 - val_accuracy: 0.9918
# Epoch 85/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0484 - val_accuracy: 0.9932
# Epoch 86/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0583 - val_accuracy: 0.9914
# Epoch 87/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0569 - val_accuracy: 0.9902
# Epoch 88/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0578 - val_accuracy: 0.9918
# Epoch 89/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0541 - val_accuracy: 0.9922
# Epoch 90/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0525 - val_accuracy: 0.9923
# Epoch 91/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0500 - val_accuracy: 0.9926
# Epoch 92/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0492 - val_accuracy: 0.9924
# Epoch 93/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0487 - val_accuracy: 0.9923
# Epoch 94/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0488 - val_accuracy: 0.9917
# Epoch 95/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0532 - val_accuracy: 0.9927
# Epoch 96/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0472 - val_accuracy: 0.9925
# Epoch 97/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0470 - val_accuracy: 0.9921
# Epoch 98/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.
200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0580 - val_accuracy: 0.9924
# Epoch 156/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0716 - val_accuracy: 0.9924
# Epoch 157/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0614 - val_accuracy: 0.9931
# Epoch 158/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0654 - val_accuracy: 0.9924
# Epoch 159/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0597 - val_accuracy: 0.9921
# Epoch 160/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0661 - val_accuracy: 0.9925
# Epoch 161/200
# 48000/48000 [==============================] - 10s 207us/sample - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0666 - val_accuracy: 0.9922
# Epoch 162/200
# 48000/48000 [==============================] - 13s 278us/sample - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0705 - val_accuracy: 0.9920
# Epoch 163/200
# 48000/48000 [==============================] - 13s 277us/sample - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0571 - val_accuracy: 0.9924
# Epoch 164/200
# 48000/48000 [==============================] - 13s 278us/sample - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0607 - val_accuracy: 0.9927
# Epoch 165/200
# 48000/48000 [==============================] - 13s 274us/sample - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0546 - val_accuracy: 0.9924
# Epoch 166/200
# 48000/48000 [==============================] - 13s 272us/sample - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0635 - val_accuracy: 0.9921
# Epoch 167/200
# 48000/48000 [==============================] - 13s 272us/sample - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0622 - val_accuracy: 0.9929
# Epoch 168/200
# 48000/48000 [==============================] - 13s 273us/sample - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0694 - val_accuracy: 0.9918
# Epoch 169/200
# 48000/48000 [==============================] - 8s 170us/sample - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0548 - val_accuracy: 0.9927
# Epoch 170/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0634 - val_accuracy: 0.9921
# Epoch 171/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0614 - val_accuracy: 0.9923
# Epoch 172/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0536 - val_accuracy: 0.9931
# Epoch 173/200
# 48000/48000 [==============================] - 14s 284us/sample - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0649 - val_accuracy: 0.9913
# Epoch 174/200
# 48000/48000 [==============================] - 13s 281us/sample - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0579 - val_accuracy: 0.9928
# Epoch 175/200
# 48000/48000 [==============================] - 13s 271us/sample - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0579 - val_accuracy: 0.9923
# Epoch 176/200
# 48000/48000 [==============================] - 13s 274us/sample - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0680 - val_accuracy: 0.9926
# Epoch 177/200
# 48000/48000 [==============================] - 13s 270us/sample - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0581 - val_accuracy: 0.9924
# Epoch 178/200
# 48000/48000 [==============================] - 14s 283us/sample - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0651 - val_accuracy: 0.9920
# Epoch 179/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0584 - val_accuracy: 0.9923
# Epoch 180/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0597 - val_accuracy: 0.9926
# Epoch 181/200
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0703 - val_accuracy: 0.9918
# Epoch 182/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0591 - val_accuracy: 0.9918
# Epoch 183/200
# 48000/48000 [==============================] - 8s 162us/sample - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0696 - val_accuracy: 0.9916
# Epoch 184/200
# 48000/48000 [==============================] - 14s 281us/sample - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0543 - val_accuracy: 0.9923
# Epoch 185/200
# 48000/48000 [==============================] - 14s 287us/sample - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0623 - val_accuracy: 0.9924
# Epoch 186/200
# 48000/48000 [==============================] - 13s 279us/sample - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0610 - val_accuracy: 0.9908
# Epoch 187/200
# 48000/48000 [==============================] - 13s 277us/sample - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.0655 - val_accuracy: 0.9911
# Epoch 188/200
# 48000/48000 [==============================] - 13s 279us/sample - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0653 - val_accuracy: 0.9915
# Epoch 189/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0685 - val_accuracy: 0.9911
# Epoch 190/200
# 48000/48000 [==============================] - 10s 203us/sample - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0680 - val_accuracy: 0.9919
# Epoch 191/200
# 48000/48000 [==============================] - 14s 282us/sample - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0590 - val_accuracy: 0.9923
# Epoch 192/200
# 48000/48000 [==============================] - 13s 276us/sample - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0807 - val_accuracy: 0.9917
# Epoch 193/200
# 48000/48000 [==============================] - 13s 276us/sample - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0707 - val_accuracy: 0.9922
# Epoch 194/200
# 48000/48000 [==============================] - 13s 280us/sample - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0653 - val_accuracy: 0.9922
# Epoch 195/200
# 48000/48000 [==============================] - 13s 267us/sample - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0632 - val_accuracy: 0.9924
# Epoch 196/200
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0621 - val_accuracy: 0.9904
# Epoch 197/200
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0715 - val_accuracy: 0.9921
# Epoch 198/200
# 48000/48000 [==============================] - 10s 210us/sample - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0652 - val_accuracy: 0.9923
# Epoch 199/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0679 - val_accuracy: 0.9925
# Epoch 200/200
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0653 - val_accuracy: 0.9922
# 10000/1 - 1s - loss: 0.0263 - accuracy: 0.9927
# Test Accuracy: 0.9927

# %%
model.save('my_model.h5')

# %%
model

# %%
from tensorflow.keras.models import load_model

model = load_model('my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-9f2802253299> in <module>
#       1 from tensorflow.keras.models import load_model
#       2
# ----> 3 model = load_model('my_model.h5')
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     164     if model_config is None:
#     165       raise ValueError('No model found in config file.')
# --> 166     model_config = json.loads(model_config.decode('utf-8'))
#     167     model = model_config_lib.model_from_config(model_config,
#     168                                                custom_objects=custom_objects)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
with open('training_history.pkl', 'rb') as file:
    loaded_history = pickle.load(file)

# 可视化加载的训练历史
plt.plot(loaded_history['accuracy'], label='Training Accuracy')
plt.plot(loaded_history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# 假设 `model` 是已经训练好的模型
# `x_test` 是测试集的输入数据
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# 假设 y_test 是真实标签，y_pred 是模型预测
y_pred_classes = np.argmax(y_pred, axis=1)  # 转换为类别
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.arange(10))
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-07f18c43322c> in <module>
# ----> 1 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#       2 import numpy as np
#       3
#       4 # 假设 y_test 是真实标签，y_pred 是模型预测
#       5 y_pred_classes = np.argmax(y_pred, axis=1)  # 转换为类别
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\sklearn\utils\__init__.py in <module>
#      21
#      22 from .murmurhash import murmurhash3_32
# ---> 23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from . import _joblib
#      25 from ..exceptions import DataConversionWarning
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\sklearn\utils\class_weight.py in <module>
#       5 import numpy as np
#       6
# ----> 7 from .validation import _deprecate_positional_args
#       8
#       9
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\sklearn\utils\validation.py in <module>
#      24 from contextlib import suppress
#      25
# ---> 26 from .fixes import _object_dtype_isnan, parse_version
#      27 from .. import get_config as _get_config
#      28 from ..exceptions import PositiveSpectrumWarning
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\sklearn\utils\fixes.py in <module>
#      18 import scipy.sparse as sp
#      19 import scipy
# ---> 20 import scipy.stats
#      21 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      22 from numpy.ma import MaskedArray as _MaskedArray  # TODO: remove in 1.0
#
# ModuleNotFoundError: No module named 'scipy.stats'

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# 假设 y_test 是真实标签，y_pred 是模型预测
y_pred_classes = np.argmax(y_pred, axis=1)  # 转换为类别
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.arange(10))
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# %%
# !pip install shap
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting shap
#   Downloading https://mirrors.aliyun.com/pypi/packages/54/15/150b1684485ae8f6f48b72bc82d17f37e0d1c9d369a080878a424d168c81/shap-0.41.0-cp36-cp36m-win_amd64.whl (435 kB)
# Requirement already satisfied: numpy in d:\anaconda\envs\tensorflow2\lib\site-packages (from shap) (1.19.5)
# Requirement already satisfied: packaging>20.9 in c:\users\administrator\appdata\roaming\python\python36\site-packages (from shap) (21.3)
# Collecting numba
#   Downloading https://mirrors.aliyun.com/pypi/packages/a7/bc/b3abeb620bc36ecbe5beec6504cd42802cf81ce5921448c29c7cbdf2d255/numba-0.53.1-cp36-cp36m-win_amd64.whl (2.3 MB)
# Requirement already satisfied: scipy in c:\users\administrator\appdata\roaming\python\python36\site-packages (from shap) (1.3.0)
# Collecting cloudpickle
#   Downloading https://mirrors.aliyun.com/pypi/packages/15/80/44286939ca215e88fa827b2aeb6fa3fd2b4a7af322485c7170d6f9fd96e0/cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting slicer==0.0.7
#   Downloading https://mirrors.aliyun.com/pypi/packages/78/c2/b3f55dfdb8af9812fdb9baf70cacf3b9e82e505b2bd4324d588888b81202/slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in d:\anaconda\envs\tensorflow2\lib\site-packages (from shap) (1.1.5)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\administrator\appdata\roaming\python\python36\site-packages (from shap) (4.32.2)
# Requirement already satisfied: scikit-learn in d:\anaconda\envs\tensorflow2\lib\site-packages (from shap) (0.24.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\envs\tensorflow2\lib\site-packages (from packaging>20.9->shap) (3.1.4)
# Requirement already satisfied: setuptools in d:\anaconda\envs\tensorflow2\lib\site-packages (from numba->shap) (58.0.4)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading https://mirrors.aliyun.com/pypi/packages/34/c4/60cd9ca9e67b9b45bd218fd78199deed0e5a17b0b6e4589172c0eda29e4d/llvmlite-0.36.0-cp36-cp36m-win_amd64.whl (16.0 MB)
# Requirement already satisfied: pytz>=2017.2 in d:\anaconda\envs\tensorflow2\lib\site-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\anaconda\envs\tensorflow2\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\envs\tensorflow2\lib\site-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda\envs\tensorflow2\lib\site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\tensorflow2\lib\site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Installing collected packages: llvmlite, slicer, numba, cloudpickle, shap
# Successfully installed cloudpickle-2.2.1 llvmlite-0.36.0 numba-0.53.1 shap-0.41.0 slicer-0.0.7

# %%
# 假设 x_train 和 y_train 是你的训练数据和标签
# 这里 model 是您已经训练好的模型

# 确保 y_train 是整数格式，而不是 one-hot 编码
# 如果 y_train 是 one-hot 编码，可以使用 np.argmax 转换
y_train_int = np.argmax(y_train, axis=1)  # 将 one-hot 编码转换为整数标签

# 使用 StratifiedKFold 进行 5 折交叉验证
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_accuracies = []  # 用于存储每个折叠的准确率

# 进行交叉验证（不重新训练，只验证）
for fold, (train_index, test_index) in enumerate(skf.split(x_train, y_train_int), 1):
    X_train, X_test = x_train[train_index], x_train[test_index]
    y_train_fold, y_test_fold = y_train_int[train_index], y_train_int[test_index]
    
    # 在验证集上评估已经训练好的模型
    y_pred = model.predict(X_test)
    
    # 计算准确率
    accuracy = np.mean(np.argmax(y_pred, axis=1) == y_test_fold)
    fold_accuracies.append(accuracy)
    print(f"Fold {fold} Accuracy: {accuracy:.4f}")

# 可视化每个折叠的准确率
plt.figure(figsize=(8, 6))
plt.plot(range(1, 6), fold_accuracies, marker='o', color='b', label='Fold Accuracy')
plt.title('5-Fold Cross-Validation Accuracy')
plt.xlabel('Fold Number')
plt.ylabel('Accuracy')
plt.xticks(range(1, 6))  # 设置 x 轴刻度为折叠编号
plt.grid(True)
plt.legend()
plt.show()

# 打印总体结果
print(f"Mean accuracy: {np.mean(fold_accuracies):.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a37d4eea7c2f> in <module>
#       7
#       8 # 使用 StratifiedKFold 进行 5 折交叉验证
# ----> 9 skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
#      10
#      11 fold_accuracies = []  # 用于存储每个折叠的准确率
#
# NameError: name 'StratifiedKFold' is not defined

# %%
import os
os.getcwd()
# Out:
# 'e:\\network assessment'

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import categorical_crossentropy

model = load_model('my_model.h5', custom_objects={'categorical_crossentropy': categorical_crossentropy})
##python版本太低，这里没导入成功，3.8以上的python即可成功导入模型
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b65138b9d381> in <module>
#       2 from tensorflow.keras.losses import categorical_crossentropy
#       3
# ----> 4 model = load_model('my_model.h5', custom_objects={'categorical_crossentropy': categorical_crossentropy})
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# d:\anaconda\envs\tensorflow2\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     164     if model_config is None:
#     165       raise ValueError('No model found in config file.')
# --> 166     model_config = json.loads(model_config.decode('utf-8'))
#     167     model = model_config_lib.model_from_config(model_config,
#     168                                                custom_objects=custom_objects)
#
# AttributeError: 'str' object has no attribute 'decode'
